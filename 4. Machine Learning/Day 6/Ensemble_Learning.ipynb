# %% [markdown]
# ![image.png](attachment:f0934f4d-121e-40ad-b493-1e4927e5a8af.png)

# %% [markdown]
# Instead of 1 decistion tree, ensemble alorithm uses the multiple DTs to improve the performance by having each DT perfect in different path.

# %% [markdown]
# ![image.png](attachment:e0843f5a-256b-4115-a7d2-53fec91011c9.png)

# %% [markdown]
# In Bagging, All the weak learner learns in parrallel or simultanouly

# %% [markdown]
# ![image.png](attachment:77439aeb-4966-4154-9715-8af90a82a053.png)
