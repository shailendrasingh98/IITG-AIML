# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(42)
population = np.random.uniform(low=0, high=100, size=10000)
sample_size =30

num_samples =1000
sample_means = [np.mean(np.random.choice(population, size=sample_size, replace=True)) for _ in range(num_samples)]
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(population, bins=50, kde=True, color='blue')
plt.title("Origianl Population Distribution(uniform)")

plt.subplot(1,2,2)
sns.histplot(sample_means, bins=50, kde=True, color='red')
plt.title("Sampling Distribution of the mean(Normal)")
plt.show()

# %%
from scipy.stats import norm
sample_mean = np.mean(sample_means)

confidence_level=0.95
sample_std = np.std(sample_means, ddof=1)
z_value = norm.ppf((1+ confidence_level)/2)
margin_of_error = z_value* sample_std
confidence_interval = sample_mean-margin_of_error, sample_mean+margin_of_error

print(f" Estimated population mean:{sample_mean:.2f}")
print(f" 95% Confidence interval: {confidence_interval}")
# Out:
#  Estimated population mean:49.65
#  95% Confidence interval: (39.550593971225766, 59.74875350651388)
