# %%
import pandas as pd

# %%
# Reading csv file
df = pd.read_csv('diamonds.csv')
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table   price     x  \
# 0             1.0   0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95
# 1             NaN    NaN        NaN   NaN     NaN    NaN    NaN     NaN   NaN
# 2             2.0   0.21    Premium     E     SI1   59.8   61.0   326.0   NaN
# 3             3.0   0.23       Good     E     VS1   56.9   65.0   327.0  4.05
# 4             4.0   0.29    Premium     I     VS2   62.4   58.0   334.0  4.20
# ...           ...    ...        ...   ...     ...    ...    ...     ...   ...
# 53936     53936.0   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75
# 53937     53937.0   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69
# 53938     53938.0   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66
# 53939     53939.0   0.86    Premium     H     SI2   61.0   58.0  2757.0  6.15
# 53940     53940.0   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83
#
#           y     z
# ...

# %%
df[df['price']<400]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0  326.0  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0  326.0   NaN
# 2               3   0.23       Good     E     VS1   56.9   65.0  327.0  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0  334.0  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0  335.0  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 50612       50613   0.26  Very Good     H     VS1   62.0   56.0  399.0  4.08
# 50613       50614   0.25  Very Good     D     VS2   61.1   60.0  399.0  4.07
# 50614       50615   0.27  Very Good     G     VS1   58.8   57.0  399.0  4.25
# 50615       50616   0.24       Good     F     VS1   62.5   60.0  399.0  3.96
# 50616       50617   0.25       Good     D     VS1   57.6   60.0  399.0  4.15
#
#           y     z
# 0      3.98  2.43
# ...

# %%
# Prices less than 400 and cut is 'premium'

df[(df['price']<400) & (df['cut']=="Premium")]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 1               2   0.21  Premium     E     SI1   59.8   61.0  326.0   NaN
# 3               4   0.29  Premium     I     VS2   62.4   58.0  334.0  4.20
# 12             13   0.22  Premium     F     SI1   60.4   61.0  342.0  3.88
# 14             15   0.20  Premium     E     SI2   60.2   62.0  345.0  3.79
# 15             16   0.32  Premium     E      I1   60.9   58.0  345.0  4.38
# 26             27   0.24  Premium     I     VS1   62.5   57.0  355.0  3.97
# 28279       28280   0.31  Premium     J     SI1   60.9   60.0  363.0  4.36
# 28284       28285   0.32  Premium     J     SI1   62.2   59.0  365.0  4.37
# 31591       31592   0.20  Premium     E     VS2   59.8   62.0  367.0  3.79
# 31592       31593   0.20  Premium     E     VS2   59.0   60.0  367.0  3.81
# 31593       31594   0.20  Premium     E     VS2   61.1   59.0  367.0  3.81
# ...

# %%
df[df.cut.isin(['Premium', 'Good'])]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table   price     x  \
# 1               2   0.21  Premium     E     SI1   59.8   61.0   326.0   NaN
# 2               3   0.23     Good     E     VS1   56.9   65.0   327.0  4.05
# 3               4   0.29  Premium     I     VS2   62.4   58.0   334.0  4.20
# 4               5   0.31     Good     J     SI2   63.3   58.0   335.0  4.34
# 10             11   0.30     Good     J     SI1   64.0   55.0   339.0  4.25
# ...           ...    ...      ...   ...     ...    ...    ...     ...   ...
# 53930       53931   0.71  Premium     E     SI1   60.5   55.0  2756.0  5.79
# 53931       53932   0.71  Premium     F     SI1   59.8   62.0  2756.0  5.74
# 53934       53935   0.72  Premium     D     SI1   62.7   59.0  2757.0  5.69
# 53936       53937   0.72     Good     D     SI1   63.1   55.0  2757.0  5.69
# 53938       53939   0.86  Premium     H     SI2   61.0   58.0  2757.0  6.15
#
#           y     z
# 1       NaN   NaN
# ...

# %%
df[(df['cut']=='Premium') | (df['cut']=='Good')]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table   price     x  \
# 1               2   0.21  Premium     E     SI1   59.8   61.0   326.0   NaN
# 2               3   0.23     Good     E     VS1   56.9   65.0   327.0  4.05
# 3               4   0.29  Premium     I     VS2   62.4   58.0   334.0  4.20
# 4               5   0.31     Good     J     SI2   63.3   58.0   335.0  4.34
# 10             11   0.30     Good     J     SI1   64.0   55.0   339.0  4.25
# ...           ...    ...      ...   ...     ...    ...    ...     ...   ...
# 53930       53931   0.71  Premium     E     SI1   60.5   55.0  2756.0  5.79
# 53931       53932   0.71  Premium     F     SI1   59.8   62.0  2756.0  5.74
# 53934       53935   0.72  Premium     D     SI1   62.7   59.0  2757.0  5.69
# 53936       53937   0.72     Good     D     SI1   63.1   55.0  2757.0  5.69
# 53938       53939   0.86  Premium     H     SI2   61.0   58.0  2757.0  6.15
#
#           y     z
# 1       NaN   NaN
# ...

# %%
df[df.clarity.str.startswith('S')]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table   price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0   326.0   NaN
# 4               5   0.31       Good     J     SI2   63.3   58.0   335.0  4.34
# 7               8   0.26  Very Good     H     SI1   61.9   55.0   337.0  4.07
# 10             11   0.30       Good     J     SI1   64.0   55.0   339.0  4.25
# ...           ...    ...        ...   ...     ...    ...    ...     ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0  2757.0  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0  2757.0  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0  2757.0  5.83
#
#           y     z
# ...

# %%
df[df.cut.str.contains('G')]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table   price     x  \
# 2               3   0.23       Good     E     VS1   56.9   65.0   327.0  4.05
# 4               5   0.31       Good     J     SI2   63.3   58.0   335.0  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0   336.0  3.94
# 6               7    NaN  Very Good     I    VVS1   62.3   57.0   336.0  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0   337.0  4.07
# ...           ...    ...        ...   ...     ...    ...    ...     ...   ...
# 53927       53928   0.79       Good     F     SI1   58.1   59.0  2756.0  6.06
# 53932       53933   0.70  Very Good     E     VS2   60.5   59.0  2757.0  5.71
# 53933       53934   0.70  Very Good     E     VS2   61.2   59.0  2757.0  5.69
# 53936       53937   0.72       Good     D     SI1   63.1   55.0  2757.0  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66
#
#           y     z
# ...

# %%
df[~df.cut.str.contains('G')]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table   price     x  \
# 0               1   0.23    Ideal     E     SI2   61.5   55.0   326.0  3.95
# 1               2   0.21  Premium     E     SI1   59.8   61.0   326.0   NaN
# 3               4   0.29  Premium     I     VS2   62.4   58.0   334.0  4.20
# 8               9   0.22     Fair     E     VS2   65.1   61.0   337.0  3.87
# 11             12   0.23    Ideal     J     VS1   62.8   56.0   340.0  3.93
# ...           ...    ...      ...   ...     ...    ...    ...     ...   ...
# 53931       53932   0.71  Premium     F     SI1   59.8   62.0  2756.0  5.74
# 53934       53935   0.72  Premium     D     SI1   62.7   59.0  2757.0  5.69
# 53935       53936   0.72    Ideal     D     SI1   60.8   57.0  2757.0  5.75
# 53938       53939   0.86  Premium     H     SI2   61.0   58.0  2757.0  6.15
# 53939       53940   0.75    Ideal     D     SI2   62.2   55.0  2757.0  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.query('price < 400 and cut == "Premium"')
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 1               2   0.21  Premium     E     SI1   59.8   61.0  326.0   NaN
# 3               4   0.29  Premium     I     VS2   62.4   58.0  334.0  4.20
# 12             13   0.22  Premium     F     SI1   60.4   61.0  342.0  3.88
# 14             15   0.20  Premium     E     SI2   60.2   62.0  345.0  3.79
# 15             16   0.32  Premium     E      I1   60.9   58.0  345.0  4.38
# 26             27   0.24  Premium     I     VS1   62.5   57.0  355.0  3.97
# 28279       28280   0.31  Premium     J     SI1   60.9   60.0  363.0  4.36
# 28284       28285   0.32  Premium     J     SI1   62.2   59.0  365.0  4.37
# 31591       31592   0.20  Premium     E     VS2   59.8   62.0  367.0  3.79
# 31592       31593   0.20  Premium     E     VS2   59.0   60.0  367.0  3.81
# 31593       31594   0.20  Premium     E     VS2   61.1   59.0  367.0  3.81
# ...

# %%
df[df.cut.str.contains('P')]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table   price     x  \
# 1               2   0.21  Premium     E     SI1   59.8   61.0   326.0   NaN
# 3               4   0.29  Premium     I     VS2   62.4   58.0   334.0  4.20
# 12             13   0.22  Premium     F     SI1   60.4   61.0   342.0  3.88
# 14             15   0.20  Premium     E     SI2   60.2   62.0   345.0  3.79
# 15             16   0.32  Premium     E      I1   60.9   58.0   345.0  4.38
# ...           ...    ...      ...   ...     ...    ...    ...     ...   ...
# 53928       53929   0.79  Premium     E     SI2   61.4   58.0  2756.0  6.03
# 53930       53931   0.71  Premium     E     SI1   60.5   55.0  2756.0  5.79
# 53931       53932   0.71  Premium     F     SI1   59.8   62.0  2756.0  5.74
# 53934       53935   0.72  Premium     D     SI1   62.7   59.0  2757.0  5.69
# 53938       53939   0.86  Premium     H     SI2   61.0   58.0  2757.0  6.15
#
#           y     z
# 1       NaN   NaN
# ...

# %%
df[df['cut']>'P']
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table   price     x  \
# 1               2   0.21    Premium     E     SI1   59.8   61.0   326.0   NaN
# 3               4   0.29    Premium     I     VS2   62.4   58.0   334.0  4.20
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0   336.0  3.94
# 6               7    NaN  Very Good     I    VVS1   62.3   57.0   336.0  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0   337.0  4.07
# ...           ...    ...        ...   ...     ...    ...    ...     ...   ...
# 53932       53933   0.70  Very Good     E     VS2   60.5   59.0  2757.0  5.71
# 53933       53934   0.70  Very Good     E     VS2   61.2   59.0  2757.0  5.69
# 53934       53935   0.72    Premium     D     SI1   62.7   59.0  2757.0  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0  2757.0  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0  2757.0  6.15
#
#           y     z
# ...

# %%
df[df.cut.str.startswith('P')]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table   price     x  \
# 1               2   0.21  Premium     E     SI1   59.8   61.0   326.0   NaN
# 3               4   0.29  Premium     I     VS2   62.4   58.0   334.0  4.20
# 12             13   0.22  Premium     F     SI1   60.4   61.0   342.0  3.88
# 14             15   0.20  Premium     E     SI2   60.2   62.0   345.0  3.79
# 15             16   0.32  Premium     E      I1   60.9   58.0   345.0  4.38
# ...           ...    ...      ...   ...     ...    ...    ...     ...   ...
# 53928       53929   0.79  Premium     E     SI2   61.4   58.0  2756.0  6.03
# 53930       53931   0.71  Premium     E     SI1   60.5   55.0  2756.0  5.79
# 53931       53932   0.71  Premium     F     SI1   59.8   62.0  2756.0  5.74
# 53934       53935   0.72  Premium     D     SI1   62.7   59.0  2757.0  5.69
# 53938       53939   0.86  Premium     H     SI2   61.0   58.0  2757.0  6.15
#
#           y     z
# 1       NaN   NaN
# ...

# %%
df.nlargest(3, 'price')
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table    price  \
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823.0
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818.0
# 27747       27748   1.51      Ideal     G      IF   61.7   55.0  18806.0
#
#           x     y     z
# 27749  8.50  8.47  5.16
# 27748  7.90  7.97  5.04
# 27747  7.37  7.41  4.56

# %%
df.nsmallest(3, 'price')
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0  326.0  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0  326.0   NaN   NaN
# 2           3   0.23     Good     E     VS1   56.9   65.0  327.0  4.05  4.07
#
#       z
# 0  2.43
# 1   NaN
# 2  2.31

# %%
# print all rows where any of the column value is None.
df[df.isnull().any(axis=1)]
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 1            2   0.21    Premium     E     SI1   59.8   61.0  326.0   NaN
# 6            7    NaN  Very Good     I    VVS1   62.3   57.0  336.0  3.95
# 18          19   0.30       Good     J     SI1   63.8   56.0    NaN  4.23
# 23          24   0.31  Very Good     J     SI1    NaN   62.0  353.0  4.39
#
#        y     z
# 1    NaN   NaN
# 6   3.98  2.47
# 18  4.26  2.71
# 23  4.43  2.62

# %%
# print all rows where all columns values are None
df[df.isnull().all(axis=1)]
# Out:
#    Unnamed: 0  carat  cut color clarity  depth  table  price   x   y   z
# 1         NaN    NaN  NaN   NaN     NaN    NaN    NaN    NaN NaN NaN NaN
